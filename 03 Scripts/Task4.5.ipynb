# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\johan\Documents\Insta Basket Analysis'

# %%
path
# Out:
# 'C:\\Users\\johan\\Documents\\Insta Basket Analysis'

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# %%
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
# 2. Run the df.describe() function on your df_ords dataframe. 
# Using your new knowledge about how to interpret the output of this function, 
# share in a markdown cell whether anything about the data looks off or should be investigated further.

# %%
df_ords.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06        3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01        2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01        2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00        1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01        3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# ...

# %%
# 3. Check for mixed-type data in your df_ords dataframe.

# %%
for col in df_ords.columns.tolist():
  weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords[weird]) > 0:
    print (col)
# Out:
# C:\Users\johan\AppData\Local\Temp\ipykernel_7428\1946670780.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\johan\AppData\Local\Temp\ipykernel_7428\1946670780.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\johan\AppData\Local\Temp\ipykernel_7428\1946670780.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# C:\Users\johan\AppData\Local\Temp\ipykernel_7428\1946670780.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   weird = (df_ords[[col]].applymap(type) != df_ords[[col]].iloc[0].apply(type)).any(axis = 1)
# ...

# %%
df_ords.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   orders_day_of_week      int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 182.7+ MB

# %%
# 4. If you find mixed-type data, fix it. The column in question should contain observations of a single data type.

# %%
# No

# %%
# 5. Run a check for missing values in your df_ords dataframe.
#    In a markdown cell, report your findings and propose an explanation for any missing values you find.

# %%
df_ords.isnull().sum()
# Out:
# order_id                       0
# user_id                        0
# eval_set                       0
# order_number                   0
# orders_day_of_week             0
# order_hour_of_day              0
# days_since_prior_order    206209
# dtype: int64

# %%
df_nan = df_ords[df_ords['days_since_prior_order'].isnull() == True]

# %%
df_nan
# Out:
#          order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0         2539329        1    prior             1                   2
# 11        2168274        2    prior             1                   2
# 26        1374495        3    prior             1                   1
# 39        3343014        4    prior             1                   6
# 45        2717275        5    prior             1                   3
# ...           ...      ...      ...           ...                 ...
# 3420930    969311   206205    prior             1                   4
# 3420934   3189322   206206    prior             1                   3
# 3421002   2166133   206207    prior             1                   6
# 3421019   2227043   206208    prior             1                   1
# 3421069   3154581   206209    prior             1                   3
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# ...

# %%
# 6. Address the missing values using an appropriate method.

# %%
# this missing value 6% from whole row, this cannot be deleted, and seem this caused by system failure
# This could be 0 or but since there also 0 value and there is no outlier then I change it to mean value =

# %%
df_ords.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06        3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01        2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01        2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00        1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01        3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# ...

# %%
# counting descriptive statistic
mean_days = df_ords['days_since_prior_order'].mean()
median_days = df_ords['days_since_prior_order'].median()
max_days = df_ords['days_since_prior_order'].max()
min_days = df_ords['days_since_prior_order'].min()

#  show the result
print("📊 Statistik kolom 'days_since_prior_order'")
print("-------------------------------------------")
print("Rata-rata (mean)  :", mean_days)
print("Median            :", median_days)
print("Nilai maksimum    :", max_days)
print("Nilai minimum     :", min_days)
# Out:
# 📊 Statistik kolom 'days_since_prior_order'
# -------------------------------------------
# Rata-rata (mean)  : 11.114836226863012
# Median            : 7.0
# Nilai maksimum    : 30.0
# Nilai minimum     : 0.0

# %%
# change the missing with mean

# %%
df_ords['days_since_prior_order'].fillna(11.114836226863012, inplace=True)
# Out:
# C:\Users\johan\AppData\Local\Temp\ipykernel_7428\3692842328.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_ords['days_since_prior_order'].fillna(11.114836226863012, inplace=True)

# %%
df_ords.isnull().sum()
# Out:
# order_id                  0
# user_id                   0
# eval_set                  0
# order_number              0
# orders_day_of_week        0
# order_hour_of_day         0
# days_since_prior_order    0
# dtype: int64

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %%
df_ords_clean = df_ords[df_ords['days_since_prior_order'].isnull() == False]

# %%
df_ords_clean.shape
# Out:
# (3421083, 7)

# %%
# 7. Run a check for duplicate values in your df_ords data.

# %%
df_dups = df_ords_clean[df_ords_clean.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, eval_set, order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order]
# Index: []

# %%
df_dups.shape
# Out:
# (0, 7)

# %%
# No duplicate

# %%
# 9. Export your final, cleaned df_prods and df_ords data as “.csv” files in your “Prepared Data” folder and give them appropriate, succinct names.

# %%
df_ords_clean.to_csv(os.path.join(path, '02 Data','Prepared Data', 'df_ords_clean.csv'))

# %%
df_ords_clean.describe()
# Out:
#            order_id       user_id  order_number  orders_day_of_week  \
# count  3.421083e+06  3.421083e+06  3.421083e+06        3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01        2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01        2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00        0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00        1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01        3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01        5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02        6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.421083e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            8.924952e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            5.000000e+00
# 50%         1.300000e+01            8.000000e+00
# ...

# %%
df_ords_clean.isnull().sum()
# Out:
# order_id                  0
# user_id                   0
# eval_set                  0
# order_number              0
# orders_day_of_week        0
# order_hour_of_day         0
# days_since_prior_order    0
# dtype: int64

# %%
df_ords_clean.shape
# Out:
# (3421083, 7)

# %%
df_ords_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   orders_day_of_week      int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 182.7+ MB
