# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\johan\Documents\Insta Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_ex7.pkl'))

# %%
ords_prods_merge.shape
# Out:
# (32404859, 18)

# %%
# 2.

# %%
ords_prods_merge.groupby('product_name')

# %% [markdown]
# # Grouping Data with pandas

# %%
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %%
ords_prods_merge.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     15.457838
# 2     17.277920
# 3     17.170395
# 4     17.811403
# 5     15.215751
# 6     16.439806
# 7     17.225802
# 8     15.340650
# 9     15.895474
# 10    20.197148
# 11    16.170638
# 12    15.887671
# 13    16.583536
# 14    16.773669
# 15    16.165037
# 16    17.665606
# 17    15.694469
# 18    19.310397
# 19    17.177343
# 20    16.473447
# 21    22.902379
# Name: order_number, dtype: float64

# %%
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                15.457838   1  99
# 2                17.277920   1  99
# 3                17.170395   1  99
# 4                17.811403   1  99
# 5                15.215751   1  99
# 6                16.439806   1  99
# 7                17.225802   1  99
# 8                15.340650   1  99
# 9                15.895474   1  99
# 10               20.197148   1  99
# 11               16.170638   1  99
# 12               15.887671   1  99
# 13               16.583536   1  99
# 14               16.773669   1  99
# 15               16.165037   1  99
# 16               17.665606   1  99
# 17               15.694469   1  99
# 18               19.310397   1  99
# 19               17.177343   1  99
# 20               16.473447   1  99
# 21               22.902379   1  99

# %%
# 3. Analyze the result. How do the results for the entire dataframe

# %%
# Cek if all rows dataset included
total_rows = ords_prods_merge.shape[0]
print(f"Total rows in dataset: {total_rows}")

# Count total rows in groupby
rows_in_groupby = ords_prods_merge.groupby('department_id')['order_number'].count().sum()
print(f"Total rows in groupby: {rows_in_groupby}")

# Compare if they are same
if total_rows == rows_in_groupby:
    print("✅ All ROW counted by groupby!")
else:
    print("❌ These are any ROW not included groupby!")
# Out:
# Total rows in dataset: 32404859
# Total rows in groupby: 32404859
# ✅ All ROW counted by groupby!

# %%
# 4

# %% [markdown]
# # Aggregating Data with transform

# %%
# Create a loyalty flag using loc

# %%
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\johan\AppData\Local\Temp\ipykernel_8280\1681540670.py:1: FutureWarning: The provided callable <function max at 0x00000254769FAAC0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
ords_prods_merge.shape
# Out:
# (32404859, 19)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2539329        1    prior             1                   2
# 2    2539329        1    prior             1                   2
# 3    2539329        1    prior             1                   2
# 4    2539329        1    prior             1                   2
# 5    2398795        1    prior             2                   3
# 6    2398795        1    prior             2                   3
# 7    2398795        1    prior             2                   3
# 8    2398795        1    prior             2                   3
# 9    2398795        1    prior             2                   3
# 10   2398795        1    prior             2                   3
# 11    473747        1    prior             3                   3
# 12    473747        1    prior             3                   3
# ...

# %%
ords_prods_merge.head(100)
# Out:
#     order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0    2539329        1    prior             1                   2
# 1    2539329        1    prior             1                   2
# 2    2539329        1    prior             1                   2
# 3    2539329        1    prior             1                   2
# 4    2539329        1    prior             1                   2
# ..       ...      ...      ...           ...                 ...
# 95    738281        2    prior             4                   2
# 96   1673511        2    prior             5                   3
# 97   1673511        2    prior             5                   3
# 98   1673511        2    prior             5                   3
# 99   1673511        2    prior             5                   3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                   8               11.114836         196                  1
# ...

# %%
pd.options.display.max_rows = None

# %% [markdown]
# # Deriving Columns with loc()

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna=False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge.shape
# Out:
# (32404859, 20)

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# ...

# %%
# 5.

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'order_number': ['count','mean', 'median', 'min', 'max','std']})
# Out:
#                  order_number
#                         count       mean median min max        std
# loyalty_flag
# Loyal customer       10284093  32.641196   30.0   1  99  21.699721
# New customer          6243990   3.807044    3.0   1  10   2.295622
# Regular customer     15876776  12.347452   11.0   1  40   8.484249

# %%
# intrepetation:

# %%
# Loyal customer: Mean 32 = average spending 32 times > median 30

# %%
# > There is a small percentage of loyal customers who shop very frequently (even up to 99x!), so the average is higher than the median value.

# %%
# New customer: Mean 4 average spend 4 times, median 3 half of them spend three times or more

# %%
# >There is a small percentage of new customers who shop very frequently , so the average is higher than the median value.

# %%
# Regular customer:Mean 12 average 12 times meanwhile median11 halh of them spend 11 times or more

# %%
# > There is a small percentage of regular customers who shop very frequently , so the average is higher than the median value.

# %%
# determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customer

# %%
# Statistik price per loyalty_flag
price_analysis = ords_prods_merge.groupby('loyalty_flag')['prices'].agg([
    'mean', 'median', 'min', 'max', 'std', 'count'
]).round(2)

print("ANALYSIS of PRODUCR PRICE per LOYALTY_FLAG:")
print(price_analysis)
# Out:
# ANALYSIS of PRODUCR PRICE per LOYALTY_FLAG:
#                    mean  median  min      max     std     count
# loyalty_flag
# Loyal customer    10.39     7.4  1.0  99999.0  328.02  10284093
# New customer      13.29     7.4  1.0  99999.0  597.56   6243990
# Regular customer  12.50     7.4  1.0  99999.0  539.72  15876776

# %%
ords_prods_merge.head(1)

# %%
# 6

# %%
# Create a loyalty flag using loc

# %%
ords_prods_merge['mean_prices'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\johan\AppData\Local\Temp\ipykernel_8280\3812100117.py:1: FutureWarning: The provided callable <function mean at 0x00000254769FB4C0> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   ords_prods_merge['mean_prices'] = ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
ords_prods_merge.head(1)
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8               11.114836         196                  1
#
#    reordered  ... department_id  prices        price_label     busiest_day  \
# 0          0  ...             7     9.0  Mid-range product  Regularly busy
#
#      Busiest_days busiest_period_of_day. max_order       loyalty_flag  \
# 0  Regularly busy         Average orders        10  Regular customer.
#
#    mean_prices cust_frequent
# 0     6.367797          20.0
#
# [1 rows x 22 columns]

# %%
# Deriving Columns with loc()

# %%
ords_prods_merge.loc[ords_prods_merge['mean_prices'] < 10, 'spender_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['mean_prices'] >= 10, 'spender_flag'] = 'High spender'

# %%
ords_prods_merge['spender_flag'].value_counts(dropna=False)
# Out:
# spender_flag
# Low spender     31770614
# High spender      634245
# Name: count, dtype: int64

# %%
ords_prods_merge.head(1)
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8               11.114836         196                  1
#
#    reordered  ... prices        price_label     busiest_day    Busiest_days  \
# 0          0  ...    9.0  Mid-range product  Regularly busy  Regularly busy
#
#   busiest_period_of_day. max_order       loyalty_flag mean_prices  \
# 0         Average orders        10  Regular customer.    6.367797
#
#    cust_frequent spender_flag
# 0           20.0  Low spender
#
# [1 rows x 23 columns]

# %%
ords_prods_merge[['user_id', 'spender_flag', 'prices']].head(60)
# Out:
#     user_id spender_flag  prices
# 0         1  Low spender     9.0
# 1         1  Low spender    12.5
# 2         1  Low spender     4.4
# 3         1  Low spender     4.7
# 4         1  Low spender     1.0
# 5         1  Low spender     9.0
# 6         1  Low spender     3.0
# 7         1  Low spender     4.4
# 8         1  Low spender    10.3
# 9         1  Low spender     4.7
# 10        1  Low spender     4.0
# 11        1  Low spender     9.0
# 12        1  Low spender     4.4
# 13        1  Low spender     3.0
# 14        1  Low spender     8.6
# 15        1  Low spender     3.2
# 16        1  Low spender     9.0
# 17        1  Low spender     4.4
# 18        1  Low spender     3.0
# 19        1  Low spender     8.6
# 20        1  Low spender     1.0
# 21        1  Low spender     9.0
# 22        1  Low spender     4.4
# 23        1  Low spender     3.0
# 24        1  Low spender     8.6
# 25        1  Low spender     2.7
# 26        1  Low spender    14.0
# ...

# %%
# 7

# %%
# Create a loyalty flag using loc

# %%
ords_prods_merge['cust_frequent'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# C:\Users\johan\AppData\Local\Temp\ipykernel_8280\3846229924.py:1: FutureWarning: The provided callable <function median at 0x0000025476B52A20> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   ords_prods_merge['cust_frequent'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Deriving Columns with loc()

# %%
ords_prods_merge.loc[ords_prods_merge['cust_frequent'] > 20, 'freq_flag'] = 'Non-frequent customer.'

# %%
ords_prods_merge.loc[(ords_prods_merge['cust_frequent'] > 10) & (ords_prods_merge['cust_frequent'] <= 20), 'freq_flag'] = 'Regular customer.'

# %%
ords_prods_merge.loc[ords_prods_merge['cust_frequent'] <= 10, 'freq_flag'] = 'Frequent customer.'

# %%
ords_prods_merge['freq_flag'].value_counts(dropna=False)
# Out:
# freq_flag
# Frequent customer.        20535136
# Regular customer.          9168905
# Non-frequent customer.     2700818
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'freq_flag', 'cust_frequent']].head(60)
# Out:
#     user_id          freq_flag  cust_frequent
# 0         1  Regular customer.           20.0
# 1         1  Regular customer.           20.0
# 2         1  Regular customer.           20.0
# 3         1  Regular customer.           20.0
# 4         1  Regular customer.           20.0
# 5         1  Regular customer.           20.0
# 6         1  Regular customer.           20.0
# 7         1  Regular customer.           20.0
# 8         1  Regular customer.           20.0
# 9         1  Regular customer.           20.0
# 10        1  Regular customer.           20.0
# 11        1  Regular customer.           20.0
# 12        1  Regular customer.           20.0
# 13        1  Regular customer.           20.0
# 14        1  Regular customer.           20.0
# 15        1  Regular customer.           20.0
# 16        1  Regular customer.           20.0
# 17        1  Regular customer.           20.0
# 18        1  Regular customer.           20.0
# ...

# %%
ords_prods_merge.head(1)
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8               11.114836         196                  1
#
#    reordered  ...        price_label     busiest_day    Busiest_days  \
# 0          0  ...  Mid-range product  Regularly busy  Regularly busy
#
#    busiest_period_of_day. max_order       loyalty_flag mean_prices  \
# 0          Average orders        10  Regular customer.    6.367797
#
#   cust_frequent  spender_flag          freq_flag
# 0          20.0   Low spender  Regular customer.
#
# [1 rows x 24 columns]

# %%
#8

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_task4.8.pkl'))

# %%
ords_prods_merge.head(1)
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8               11.114836         196                  1
#
#    reordered  ...        price_label     busiest_day    Busiest_days  \
# 0          0  ...  Mid-range product  Regularly busy  Regularly busy
#
#    busiest_period_of_day. max_order       loyalty_flag mean_prices  \
# 0          Average orders        10  Regular customer.    6.367797
#
#   cust_frequent  spender_flag          freq_flag
# 0          20.0   Low spender  Regular customer.
#
# [1 rows x 24 columns]
