# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\johan\Documents\Insta Basket Analysis'

# %%
# 3. In a new notebook, import the orders_products_combined dataframe from the pickle file you just saved.

# %%
orders_products_combined = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.pkl'))

# %%
# 4. Check the shape of the imported dataframe (it should be the same as the one you exported—always check!).

# %%
orders_products_combined.shape
# Out:
# (32434489, 11)

# %%
#checking the column of the orders_product_combine 
orders_products_combined.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# 3          0   both
# 4          0   both

# %%
 # 5. Determine a suitable way to combine the orders_products_combined dataframe with your products data set. 
# Make sure you’re using your wrangled, cleaned, and deduped products data set stored in your “Prepared Data” folder from the previous Exercise’s task.

# %%
df_orders_products_combined = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_combined.csv'), index_col = False)

# %%
df_ords_clean = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'df_ords_clean.csv'), index_col = False)

# %%
#check the output
df_ords_clean.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           1   2398795        1    prior             2                   3
# 2           2    473747        1    prior             3                   3
# 3           3   2254736        1    prior             4                   4
# 4           4    431534        1    prior             5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8               11.114836
# 1                  7               15.000000
# 2                 12               21.000000
# 3                  7               29.000000
# 4                 15               28.000000

# %%
df_ords_clean.shape
# Out:
# (3421083, 8)

# %%
df_orders_products_combined.shape
# Out:
# (32434489, 12)

# %%
df_orders_products_combined.head()
# Out:
#    Unnamed: 0  order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0           0   2539329        1    prior             1                   2
# 1           1   2539329        1    prior             1                   2
# 2           2   2539329        1    prior             1                   2
# 3           3   2539329        1    prior             1                   2
# 4           4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# 3          0   both
# 4          0   both

# %%
#df_merged_large = df_ords_clean.merge(df_orders_products_combined, on = 'order_id', indicator = True)

# %%
df_merged_large = df_ords_clean.merge(df_orders_products_combined, on='order_id', indicator='_merge_check')

# %%
df_merged_large.head()
# Out:
#    Unnamed: 0_x  order_id  user_id_x eval_set_x  order_number_x  \
# 0             0   2539329          1      prior               1
# 1             0   2539329          1      prior               1
# 2             0   2539329          1      prior               1
# 3             0   2539329          1      prior               1
# 4             0   2539329          1      prior               1
#
#    orders_day_of_week_x  order_hour_of_day_x  days_since_prior_order_x  \
# 0                     2                    8                 11.114836
# 1                     2                    8                 11.114836
# 2                     2                    8                 11.114836
# 3                     2                    8                 11.114836
# 4                     2                    8                 11.114836
#
#    Unnamed: 0_y  user_id_y eval_set_y  order_number_y  orders_day_of_week_y  \
# 0             0          1      prior               1                     2
# 1             1          1      prior               1                     2
# 2             2          1      prior               1                     2
# 3             3          1      prior               1                     2
# 4             4          1      prior               1                     2
#
#    order_hour_of_day_y  days_since_prior_order_y  product_id  \
# 0                    8                       NaN         196
# 1                    8                       NaN       14084
# 2                    8                       NaN       12427
# 3                    8                       NaN       26088
# 4                    8                       NaN       26405
#
#    add_to_cart_order  reordered _merge _merge_check
# 0                  1          0   both         both
# 1                  2          0   both         both
# 2                  3          0   both         both
# 3                  4          0   both         both
# 4                  5          0   both         both

# %%
df_merged_large['_merge'].value_counts()
# Out:
# _merge
# both    32434489
# Name: count, dtype: int64

# %%
df_merged_large.shape
# Out:
# (32434489, 20)

# %%
# 6. Confirm the results of the merge using the merge flag.

# %%
df_merged_large1['_merge'].value_counts()
# Out:
# _merge
# both    32434489
# Name: count, dtype: int64

# %%
# 7. Export the newly created dataframe as ords_prods_merge in a suitable format (taking into consideration the size).

# %%
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge.pkl'))
