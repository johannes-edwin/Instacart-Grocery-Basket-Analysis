# %% [markdown]
# # 01 Importing libraries and Python data types

# %%
# import libraries

# %%
import pandas as pd
import numpy as np
import os

# %%
x = 2

# %%
x
# Out:
# 2

# %% [raw]
# Print (x)

# %%
type (x)
# Out:
# int

# %%
y = 5.678

# %%
type (y)
# Out:
# float

# %%
z = 'Brazil'

# %%
type (z)
# Out:
# str

# %% [raw]
# print (type (z))

# %%
type ('Mania')
# Out:
# str

# %% [raw]
# print (type('Mania'))

# %%
type (True)
# Out:
# bool

# %%
type (False)
# Out:
# bool

# %%
print(x)
# Out:
# 2

# %%
x + 4
# Out:
# 6

# %%
x = x + 4

# %%
print(x)
# Out:
# 6

# %%
a = 'Hello '

# %%
b = 'Marley'

# %%
a + b
# Out:
# 'Hello Marley'

# %%
n = 'potato'

# %%
n * 12
# Out:
# 'potatopotatopotatopotatopotatopotatopotatopotatopotatopotatopotatopotato'

# %%
x == y
# Out:
# False

# %%
type (x==y)
# Out:
# bool

# %% [markdown]
# # 02 working with Python data types.

# %%
# Code 3 different ways of reaching a result of 100 by adding or subtracting numeric variables.

# %%
x = 100

# %%
print (x)
# Out:
# 100

# %%
x = 50

# %%
x = x + x

# %%
print (x)
# Out:
# 100

# %%
y = 0

# %%
print (x+y)
# Out:
# 100

# %%
# Code 2 floating-point variables and divide them by each other.

# %%
x = 3.14

# %%
y = 2.77

# %%
print (x/y)
# Out:
# 1.1335740072202167

# %%
# Construct a short word made of separate strings (you’ll need to concatenate some strings!).

# %%
a = 'Hello '

# %%
b = 'World!'

# %%
print (a + b)
# Out:
# Hello World!

# %%
# Construct 2 short sentences made of separate strings.

# %%
c = 'Hello, Sonya. '

# %%
d = 'How are you today?'

# %%
print (c+d)
# Out:
# Hello, Sonya. How are you today?
