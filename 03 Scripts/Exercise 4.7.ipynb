# %%
import pandas as pd
import numpy as np
import os

# %%
# Define fuction
def add_num(x,y):
    sum = x + y
    return sum

# %%
# Run function
add_num(9,11)
# Out:
# 20

# %%
path = r'C:\Users\johan\Documents\Insta Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))

# %%
ords_prods_merge.shape
# Out:
# (32404859, 14)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8               11.114836         196                  1
# 1                  8               11.114836       14084                  2
# 2                  8               11.114836       12427                  3
# 3                  8               11.114836       26088                  4
# 4                  8               11.114836       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
#create a subset
df = ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8               11.114836         196                  1
# 1                  8               11.114836       14084                  2
# 2                  8               11.114836       12427                  3
# 3                  8               11.114836       26088                  4
# 4                  8               11.114836       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'orders_day_of_week',
#        'order_hour_of_day', 'days_since_prior_order', 'product_id',
#        'add_to_cart_order', 'reordered', 'product_name', 'aisle_id',
#        'department_id', 'prices'],
#       dtype='object')

# %%
# define a function
def price_label(row):

  if row['prices'] <= 5:
    return 'Low range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid range product'
  elif row['prices'] > 15:
    return 'High range product'
  else: return np.nan

# %%
# Apply the function
df['prices_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\johan\AppData\Local\Temp\ipykernel_20360\2380628727.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['prices_range'] = df.apply(price_label, axis=1)

# %%
df['prices'].value_counts(dropna=False)
# Out:
# prices
# Mid range product     673183
# Low range product     314392
# High range product     12425
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 99999.0

# %%
df['prices'].min()
# Out:
# 1.0

# %% [markdown]
# # If-Statements with the loc() Function

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna=False)
# Out:
# price_range_loc
# Mid-range product     673183
# Low-range product     314392
# High-range product     12425
# Name: count, dtype: int64

# %%
ords_prods_merge.shape
# Out:
# (32404859, 14)

# %%
ords_prods_merge.head()

# %%
ords_prods_merge.loc[ords_prods_merge['prices']>15,'price_range_loc']='High-range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices']<=15) & (ords_prods_merge['prices'] > 5),'price_range_loc'] ='Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <=5, 'price_range_loc'] = 'Low-range product'

# %% [raw]
# ords_prods_merge['price_range_loc'].value_counts(dropna=False)

# %%
print(ords_prods_merge['price_range_loc'].value_counts(dropna=False))
# Out:
# price_range_loc
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: count, dtype: int64

# %%
ords_prods_merge.shape
# Out:
# (32404859, 15)

# %%
ords_prods_merge.head()

# %% [markdown]
# # If-Statements with For-Loops

# %%
print("My Age is 30")
# Out:
# My Age is 30

# %%
print("My Age is 31")
# Out:
# My Age is 31

# %%
print("My Age is 32")
# Out:
# My Age is 32

# %%
print("My Age is 33")
# Out:
# My Age is 33

# %%
for x in range(30, 45): print ("My age is %d" % (x))
# Out:
# My age is 30
# My age is 31
# My age is 32
# My age is 33
# My age is 34
# My age is 35
# My age is 36
# My age is 37
# My age is 38
# My age is 39
# My age is 40
# My age is 41
# My age is 42
# My age is 43
# My age is 44

# %%
ords_prods_merge['orders_day_of_week'].value_counts(dropna=False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
result = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
#result

# %%
hasil = []

for x in ords_prods_merge["orders_day_of_week"]:
  if x == 0:
    hasil.append("Busiest day")
  elif x == 4:
    hasil.append("Least busy")
  else:
    hasil.append("Regularly busy")

# %%
#hasil

# %%
ords_prods_merge['busiest_day'] = result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna=False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %% [markdown]
# # Task 4.7

# %%
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\johan\Documents\Insta Basket Analysis'

# %%
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))

# %%
ords_prods_merge.shape
# Out:
# (32404859, 14)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8               11.114836         196                  1
# 1                  8               11.114836       14084                  2
# 2                  8               11.114836       12427                  3
# 3                  8               11.114836       26088                  4
# 4                  8               11.114836       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_label'] = 'High-range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5), 'price_label'] = 'Mid-range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_label'] = 'Low-range product'

# %%
ords_prods_merge['price_label'].value_counts(dropna=False)
# Out:
# price_label
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: count, dtype: int64

# %%
ords_prods_merge.shape
# Out:
# (32404859, 15)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8               11.114836         196                  1
# 1                  8               11.114836       14084                  2
# 2                  8               11.114836       12427                  3
# 3                  8               11.114836       26088                  4
# 4                  8               11.114836       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
ords_prods_merge['orders_day_of_week'].value_counts(dropna=False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
result = []

for value in ords_prods_merge["orders_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
ords_prods_merge['busiest_day'] = result

# %%
ords_prods_merge['busiest_day'].value_counts(dropna=False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %%
ords_prods_merge.shape
# Out:
# (32404859, 16)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8               11.114836         196                  1
# 1                  8               11.114836       14084                  2
# 2                  8               11.114836       12427                  3
# 3                  8               11.114836       26088                  4
# 4                  8               11.114836       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
# 2. Task 2

# %%
results = []

for value in ords_prods_merge["orders_day_of_week"]:
    if value in [0, 1]:
        results.append("Busiest days")
    elif value in [3, 4]:
        results.append("Least busy days")
    else:
        results.append("Regularly busy")

# %%
ords_prods_merge['Busiest_days'] = results

# %%
ords_prods_merge['Busiest_days'].value_counts(dropna=False)
# Out:
# Busiest_days
# Regularly busy     12916111
# Busiest days       11864412
# Least busy days     7624336
# Name: count, dtype: int64

# %%
ords_prods_merge.shape
# Out:
# (32404859, 17)

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8               11.114836         196                  1
# 1                  8               11.114836       14084                  2
# 2                  8               11.114836       12427                  3
# 3                  8               11.114836       26088                  4
# 4                  8               11.114836       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
# 3. Check

# %%
ords_prods_merge['Busiest_days'].value_counts(dropna=False)
# Out:
# Busiest_days
# Regularly busy     12916111
# Busiest days       11864412
# Least busy days     7624336
# Name: count, dtype: int64

# %%
# 4

# %%
ords_prods_merge['order_hour_of_day'].value_counts(dropna=False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
results_h = []

for value in ords_prods_merge["order_hour_of_day"]:
    if value in [10, 11, 14, 15, 13, 12, 16, 9]:
        results_h.append("Most orders")
    elif value in [17, 8, 18, 19, 20, 7, 21]:
        results_h.append("Average orders")
    else:
        results_h.append("Fewest order")

# %%
ords_prods_merge['busiest_period_of_day.'] = results_h

# %%
# 5

# %%
ords_prods_merge['busiest_period_of_day.'].value_counts(dropna=False)
# Out:
# busiest_period_of_day.
# Most orders       21118071
# Average orders     9363426
# Fewest order       1923362
# Name: count, dtype: int64

# %%
ords_prods_merge.shape
# Out:
# (32404859, 18)

# %% [raw]
# ords_prods_merge.head()

# %%
# Coba dengan menampilkan lebih sedikit baris
ords_prods_merge.head(3)  # Tampilkan hanya 3 baris pertama

# Atau gunakan
ords_prods_merge.iloc[:5]  # Tampilkan 5 baris pertama
# Out:
#    order_id  user_id eval_set  order_number  orders_day_of_week  \
# 0   2539329        1    prior             1                   2
# 1   2539329        1    prior             1                   2
# 2   2539329        1    prior             1                   2
# 3   2539329        1    prior             1                   2
# 4   2539329        1    prior             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8               11.114836         196                  1
# 1                  8               11.114836       14084                  2
# 2                  8               11.114836       12427                  3
# 3                  8               11.114836       26088                  4
# 4                  8               11.114836       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
#7

# %%
# Export data to pkl

ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge_ex7.pkl'))
